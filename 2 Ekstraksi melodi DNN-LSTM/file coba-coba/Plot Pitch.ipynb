# %%
import pandas as pd
import plotly.express as px

# %%
# df_person1_praat = pd.read_csv('person00001-00001-pitchFreq-PRAAT.txt')
# df_person9_praat = pd.read_csv('person00009-00001-pitchFreq-PRAAT.txt')
df_midi_praat = pd.read_csv('Midi00001-pitchFreq-PRAAT.txt')

# df_person1_dnn = pd.read_csv('person00001-00001-pitchFreq-DNN-LSTM.csv',header=None)
# df_person9_dnn = pd.read_csv('person00009-00001-pitchFreq-DNN-LSTM.csv',header=None)
# df_midi_dnn = pd.read_csv('Midi00001-pitchFreq-DNN-LSTM.csv',header=None)

# df_midi_dnn = df_midi_dnn[0].str.split('\t', expand=True)

df_midi_praat.head()
# df_midi_dnn.head()
# Out:
#        time               pitch
# 0  0.022132   261.8563453519539
# 1  0.032132   262.3570147996738
# 2  0.042132  262.01819369128134
# 3  0.052132  261.93688312980953
# 4  0.062132  262.28669924236146

# %%
fig = px.line(df_midi_praat, x = 'time', y = 'pitch', title='')
fig.show()
# fig.add_scatter(x=df_midi_dnn[0], y=df_midi_dnn[1], mode='lines')
# fig = px.line(df_midi_dnn, x = 0, y = 1, title='')
# fig.show()
